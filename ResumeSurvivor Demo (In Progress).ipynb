# %% [markdown]
# # ResumeSurvivor Demo (In Progress)
# ## Requirements
#
# * pytorch == 1.1
# * textract==1.6.3
# * requests==2.22.0
# * Flask==1.1.1
# * gensim==3.8.0
# * sklearn==0.0
# * PyPDF2==1.26.0
# * autocorrect==0.4.4
# * nltk==3.4.5
# * contractions==0.0.21
# * textsearch==0.0.17
# * inflect==2.1.0
# * numpy==1.17.2
# * pdfminer.six==20181108
# * Python 3.6.0 |Anaconda 4.3.0 (64-bit)|
#
# Import reuired packages

# %%
import json
import sys
# from data_process import get_str_from_pdf, get_dict_for_better_tagging_by_wrong_txt
! pip install scipy==1.1.0

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
prefix = '/content/gdrive/My drive/'
customized_path = 'ResumeSurvivor/dataset/stanford-corenlp-4.0.0'
written_path = 'ResumeSurvivor/dataset/processedlist'
# company_path = '202005_RE/dataset/companyprocess'
company_path = 'ResumeSurvivor/dataset/spacyresult'
sys_path = os.path.join(prefix, customized_path)
com_path = os.path.join(prefix, company_path)
wri_path = os.path.join(prefix, written_path) 
sys.path.append(sys_path)
sys.path.append(com_path)
sys.path.append(wri_path)
# with open('./Data/resume/own_all_data_without_space.json', 'r') as j:
#     name_to_info = json.load(j)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-876b9f7a7b99> in <module>
# ----> 1 with open('/home/agwave/Data/resume/own_all_data_without_space.json', 'r') as j:
#       2     name_to_info = json.load(j)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/agwave/Data/resume/own_all_data_without_space.json'

# %%
info = name_to_info['7c7960a4d38e']
for i, v in info.items():
    print('[',i,']')
    if isinstance(v, list):
        for s in v:
            print(s)
    else:
        print(v)
    print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0001476afb0d> in <module>
# ----> 1 info = name_to_info['7c7960a4d38e']
#       2 for i, v in info.items():
#       3     print('[',i,']')
#       4     if isinstance(v, list):
#       5         for s in v:
#
# NameError: name 'name_to_info' is not defined

# %%
pdf_text = get_str_from_pdf('/home/agwave/Data/resume/resume_train_20200121/pdf/c8aaf14994ed.pdf')
print(pdf_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-49e7d1c59d33> in <module>
# ----> 1 pdf_text = get_str_from_pdf('/home/agwave/Data/resume/resume_train_20200121/pdf/c8aaf14994ed.pdf')
#       2 print(pdf_text)
#
# NameError: name 'get_str_from_pdf' is not defined

# %%
ret = get_dict_for_better_tagging_by_wrong_txt('wrong_pdf.txt')

# %%
ret['b7bcc3802b6a']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f36402ebdd71> in <module>
# ----> 1 ret['b7bcc3802b6a']
#
# NameError: name 'ret' is not defined

# %% [markdown]
# # Dataset
# * Forkaia Dataset
# * Open Source Dataset: https://drive.google.com/open?id=17M9oDPip5JFFFNJhDCBQKy8BMqoyxajU
